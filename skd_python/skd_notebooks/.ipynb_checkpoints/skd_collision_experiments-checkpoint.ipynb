# %%
import sys, os
from datetime import datetime
# Setup
skd_python_dir = os.path.dirname(os.getcwd())
if(skd_python_dir not in sys.path):
    sys.path.append(skd_python_dir)

# Import local skd_libraries
import skd_collision_tests.collision_environment.collision_env_utils as collision_env_utils
import skd_collision_tests.collision_environment.collision_environment as collision_environment
import skd_collision_tests.collision_environment.collision_experiments_loader as collision_loader
import skd_collision_tests.collision_environment.collision_data_analyser as collision_data_analyser


# Get a shared timestamtp
timestamp = datetime.now().strftime("%m-%d-%H-%M-%S")
outdir_header = "final_collision_experiments"

# %% [markdown]
# ### Using the Collision Test Environment
# The collision environment allows to quickly prototype and visualize the interactions of an implemented car controller against safe trajectories saved in a json file.
# See "/skd_trajectories/skd_trajectories_db/" for examples of the format.
#
#
# ### Usage:
# To use the module, only the following 3 steps are needed:
# - Generate a collision experiments configuration file
# - Execute experiments according to configuration file
# - Parse and analyse the data from the collision experiments' summary file

# %% [markdown]
# ### Generate a config file, given an existing safe trajectory file in json

# %%
# Example function to generate collision_exp config
def gen_collision_exp_config(output_dir):
    output_path = output_dir + "/collision_config.yaml"
    
    # Set optional configurations
    # Safe trajectory files to consider, if empty, then GUI will allow user to select
    safe_files = []
    # Controller ids in experiment
    multiplier_ids=[0.5, 0.625]
    # Number of collision experiments per safe trajectory
    num_runs=50
    # Maximum number of steps simulated per experiment
    max_num_steps=25
    # Maximum number of trajectories considered per safe trajectory file
    max_trajs_per_file=-1
    # Default controller behaviour type ("basic" only for now)
    car_controller_type="basic"
    
    collision_env_utils.gen_collision_experiments_config(output_path, safe_files, num_runs, max_num_steps, max_trajs_per_file,
                                car_controller_type, multiplier_ids)
    return output_path




# Generate the configuration file
outputdir = os.getcwd() + "/testing_output/%s_%s" % (outdir_header, timestamp) 

# Create unique output dir
try:
    os.makedirs(outputdir)
except OSError as error:
    print(error)

config_filepath = gen_collision_exp_config(outputdir)
# Out:
# [Errno 17] File exists: '/home/jimy/SKD_DEVEL/skd_python/skd_notebooks/testing_output/final_collision_experiments_06-08-09-49-00'
# {'multiplier_ids': [0.5, 0.625], 'car_controller_type': 'basic', 'num_runs': 50, 'max_num_steps': 25, 'safe_trajectory_files': ['/home/jimy/SKD_DEVEL/skd_python/skd_trajectories/skd_trajectories_db/traj_set_1.json'], 'max_trajs_per_file': -1}

# %% [markdown]
# ### Executing collision experiments from config file

# %%
#### Executing collision experiments from config file

def run_collision_env(output_dir, config_file):
    # Create a loader for the config file
    experiments_loader = collision_loader.CollisionExperimentLoader(output_dir, config_file)

    # Run experiments from the config file
    experiments_loader.run_collision_experiments()

    # Get collision summary stats
    summary_filepath = experiments_loader.get_summary_file_path()

    return summary_filepath


# Execute experiments from config
experiments_outdir = outputdir +  "/controllers" 
summary_outpath = run_collision_env(experiments_outdir, config_filepath)
# Out:
# {'car_controller_type': 'basic', 'max_num_steps': 25, 'max_trajs_per_file': -1, 'multiplier_ids': [0.5, 0.625], 'num_runs': 50, 'safe_trajectory_files': ['/home/jimy/SKD_DEVEL/skd_python/skd_trajectories/skd_trajectories_db/traj_set_1.json']}
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.500000
# - C * Kappa = 6.751100
# ...
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000
# CAR USED:
# - Kappa = 13.502200
# - Multiplier = 0.625000
# - C * Kappa = 8.438875
# - CAR STOPPING_TIME = 2.380000
# - CAR_MAX_SPEED=8.330000
# - CAR_BRAKING_RATE=-3.500000
# - CAR_DIMS: length = 4.680000, width = 1.680000

# %% [markdown]
# ### Analyse data from collision experiments from summary file

# %%
def get_collision_summary_stats(output_dir, summary_stats_file):

    """ Create a collision experiment analyser """
    collision_analyser = collision_data_analyser.CollisionExperimentDataAnalyser(summary_stats_file, output_dir)

    """ Parse the data and review it on output_dir """
    collision_analyser.get_analyzer_summary_statistics()
    

    
# Parse results
results_outdir = outputdir + "/collision_experiments_data"

try:
    os.makedirs(results_outdir)
except OSError as error:
    print(error)

get_collision_summary_stats(results_outdir, summary_outpath)
print("DONE")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-79058fc79ce9> in <module>()
#      16     print(error)
#      17
# ---> 18 get_collision_summary_stats(results_outdir, summary_outpath)
#      19 print("DONE")
#
# <ipython-input-4-79058fc79ce9> in get_collision_summary_stats(output_dir, summary_stats_file)
#       5
#       6     """ Parse the data and review it on output_dir """
# ----> 7     collision_analyser.get_analyzer_summary_statistics()
#       8
#       9
#
# /home/jimy/SKD_DEVEL/skd_python/skd_collision_tests/collision_environment/collision_data_analyser.py in get_analyzer_summary_statistics(self)
#      44             controller_summary = self.parsing_summary_data[str(controller_id)]
#      45             # Load the top level controller summary
# ---> 46             controller_summary_data = self.parse_controller_summary(controller_id, controller_summary)
#      47
#      48             # Save summary for each controller
#
# /home/jimy/SKD_DEVEL/skd_python/skd_collision_tests/collision_environment/collision_data_analyser.py in parse_controller_summary(self, controller_id, controller_summary)
#      85             # Process summary record
#      86             safe_traj_file_data= self.process_safe_traj_file_summary(
# ---> 87                                                             controller_id, safe_traj_file_summary)
#      88
#      89             # Save stats
#
# /home/jimy/SKD_DEVEL/skd_python/skd_collision_tests/collision_environment/collision_data_analyser.py in process_safe_traj_file_summary(self, controller_id, safe_traj_file_summary)
#     142
#     143             # Plot as well
# --> 144             self.plot_single_safe_trajectory(safe_traj_dir, controller_id, safe_traj_index, max_plots = -1)
#     145
#     146             # Save stats
#
# /home/jimy/SKD_DEVEL/skd_python/skd_collision_tests/collision_environment/collision_data_analyser.py in plot_single_safe_trajectory(self, safe_traj_dir, controller_id, safe_traj_index, max_plots)
#     222
#     223             # Append run collision status
# --> 224             skd_core_utils.save_plot_number(run_num, states_data, safe_traj_plotdir, collided)
#     225
#     226
#
# /home/jimy/SKD_DEVEL/skd_python/skd_core/skd_core_utils/skd_core_utils.py in save_plot_number(run_num, exp_states, output_path, status)
#     267
#     268     # Save plot
# --> 269     plt.savefig(output_path +"/plot_%d.png" % (run_num), transparent=False, facecolor='white')
#     270     plt.close()
#     271
#
# /home/jimy/.local/lib/python3.6/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     857 def savefig(*args, **kwargs):
#     858     fig = gcf()
# --> 859     res = fig.savefig(*args, **kwargs)
#     860     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     861     return res
#
# /home/jimy/.local/lib/python3.6/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2309                 patch.set_edgecolor('none')
#    2310
# -> 2311         self.canvas.print_figure(fname, **kwargs)
#    2312
#    2313         if transparent:
#
# /home/jimy/.local/lib/python3.6/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2215                     orientation=orientation,
#    2216                     bbox_inches_restore=_bbox_inches_restore,
# -> 2217                     **kwargs)
#    2218             finally:
#    2219                 if bbox_inches and restore_bbox:
#
# /home/jimy/.local/lib/python3.6/site-packages/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1637             kwargs.pop(arg)
#    1638
# -> 1639         return func(*args, **kwargs)
#    1640
#    1641     return wrapper
#
# /home/jimy/.local/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     507             *metadata*, including the default 'Software' key.
#     508         """
# --> 509         FigureCanvasAgg.draw(self)
#     510         mpl.image.imsave(
#     511             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#
# /home/jimy/.local/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     405              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     406               else nullcontext()):
# --> 407             self.figure.draw(self.renderer)
#     408             # A GUI class may be need to update a window using this draw, so
#     409             # don't forget to call the superclass.
#
# /home/jimy/.local/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# /home/jimy/.local/lib/python3.6/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1862             self.patch.draw(renderer)
#    1863             mimage._draw_list_compositing_images(
# -> 1864                 renderer, self, artists, self.suppressComposite)
#    1865
#    1866             renderer.close_group('figure')
#
# /home/jimy/.local/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# /home/jimy/.local/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# /home/jimy/.local/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# /home/jimy/.local/lib/python3.6/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2745             renderer.stop_rasterizing()
#    2746
# -> 2747         mimage._draw_list_compositing_images(renderer, self, artists)
#    2748
#    2749         renderer.close_group('axes')
#
# /home/jimy/.local/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# /home/jimy/.local/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# /home/jimy/.local/lib/python3.6/site-packages/matplotlib/text.py in draw(self, renderer)
#    1888         if renderer is not None:
#    1889             self._renderer = renderer
# -> 1890         if not self.get_visible() or not self._check_xy(renderer):
#    1891             return
#    1892         self.update_positions(renderer)
#
# /home/jimy/.local/lib/python3.6/site-packages/matplotlib/text.py in _check_xy(self, renderer)
#    1483         if b or (b is None and self.xycoords == "data"):
#    1484             # check if self.xy is inside the axes.
# -> 1485             xy_pixel = self._get_position_xy(renderer)
#    1486             return self.axes.contains_point(xy_pixel)
#    1487         return True
#
# /home/jimy/.local/lib/python3.6/site-packages/matplotlib/text.py in _get_position_xy(self, renderer)
#    1476         """Return the pixel position of the annotated point."""
#    1477         x, y = self.xy
# -> 1478         return self._get_xy(renderer, x, y, self.xycoords)
#    1479
#    1480     def _check_xy(self, renderer):
#
# /home/jimy/.local/lib/python3.6/site-packages/matplotlib/text.py in _get_xy(self, renderer, x, y, s)
#    1347         if s2 == 'data':
#    1348             y = float(self.convert_yunits(y))
# -> 1349         return self._get_xy_transform(renderer, s).transform((x, y))
#    1350
#    1351     def _get_xy_transform(self, renderer, s):
#
# /home/jimy/.local/lib/python3.6/site-packages/matplotlib/transforms.py in transform(self, values)
#    1420
#    1421         # Transform the values
# -> 1422         res = self.transform_affine(self.transform_non_affine(values))
#    1423
#    1424         # Convert the result back to the shape of the input values.
#
# /home/jimy/.local/lib/python3.6/site-packages/matplotlib/transforms.py in transform_affine(self, points)
#    2342     def transform_affine(self, points):
#    2343         # docstring inherited
# -> 2344         return self.get_affine().transform(points)
#    2345
#    2346     def transform_non_affine(self, points):
#
# /home/jimy/.local/lib/python3.6/site-packages/matplotlib/transforms.py in get_affine(self)
#    2370         else:
#    2371             return Affine2D(np.dot(self._b.get_affine().get_matrix(),
# -> 2372                                    self._a.get_affine().get_matrix()))
#    2373
#    2374     def inverted(self):
#
# /home/jimy/.local/lib/python3.6/site-packages/matplotlib/transforms.py in __init__(self, matrix, **kwargs)
#    1840         If *matrix* is None, initialize with the identity transform.
#    1841         """
# -> 1842         Affine2DBase.__init__(self, **kwargs)
#    1843         if matrix is None:
#    1844             # A bit faster than np.identity(3).
#
# /home/jimy/.local/lib/python3.6/site-packages/matplotlib/transforms.py in __init__(self, *args, **kwargs)
#    1701
#    1702     def __init__(self, *args, **kwargs):
# -> 1703         Transform.__init__(self, *args, **kwargs)
#    1704         self._inverted = None
#    1705
#
# /home/jimy/.local/lib/python3.6/site-packages/matplotlib/transforms.py in __init__(self, shorthand_name)
#     114             ``str(transform)`` when DEBUG=True.
#     115         """
# --> 116         self._parents = {}
#     117
#     118         # TransformNodes start out as invalid until their values are
#
# KeyboardInterrupt:
