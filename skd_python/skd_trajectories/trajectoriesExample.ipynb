# %% [markdown]
# ## Custom Trajectory Generation Example

# %%
# %matplotlib inline
## Generate samples of safe trajectory using the skd_trajectories/trajectories_generators.py
import trajectories_generators as traj_gens
import os
from datetime import datetime

timestamp = datetime.now().strftime("%m-%d-%H-%M-%S")
# Define bounds for start, mid, end points of the safe trajectory
start_bounds = [122, 118]
mid_bounds = [120, 118]
end_bounds = [121, 119]

NUM_STEPS_HALF_1 = 5
NUM_STEPS_HALF_2 = 1

# Define number of safe trajs to generate
NUM_SAMPLES = 10

# Print sample safe trajectory sets
sampled_trajs = traj_gens.sample_safe_trajectory_set(start_bounds, mid_bounds, end_bounds, num_trajs = NUM_SAMPLES,
                                                    steps_half1 = NUM_STEPS_HALF_1, steps_half2 = NUM_STEPS_HALF_2)


# Save trajectories
trajectories_db = os.getcwd() + "/skd_trajectories_db"
save_path = trajectories_db + "/sample_safe_traj.json"
traj_gens.save_trajs_to_json(sampled_trajs, save_path)
# Out:
# Plotting sampled trajectory number 0
# Plotting sampled trajectory number 1
# Plotting sampled trajectory number 2
# Plotting sampled trajectory number 3
# Plotting sampled trajectory number 4
# Plotting sampled trajectory number 5
# Plotting sampled trajectory number 6
# Plotting sampled trajectory number 7
# Plotting sampled trajectory number 8
# Plotting sampled trajectory number 9
